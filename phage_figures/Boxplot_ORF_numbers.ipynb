# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## <1> Creates the boxplot of 11 species : Number of open reading frames
# - Date : 23/06/24
# - Author : Jeesu Lee

# %% [markdown]
# ##### step1. creates the boxplot

# %%
csv_ORF = "D:\Bacteriophage\ESKAPE\Statistics_all_ORF_final.csv"
df_ORF = pd.read_csv(csv_ORF)

# %%
df_ORF.replace(0, float('nan'), inplace=True)

# %%
plt.figure(figsize=(15, 6))

colors = ['#1f77b4',
        '#ff7f0e',
        '#2ca02c',
        '#d62728', 
        '#9467bd',
        '#8c564b', 
        '#e377c2',
        '#7f7f7f',
        '#bcbd22',
        '#17becf',
        '#8c6d31'
]

sns.boxplot(data=df_ORF, palette=colors)

plt.xlabel('Species')
plt.ylabel('Number of open reading frames')
plt.title('Boxplot of open reading frames by the host ESKAPE pathogen')

plt.xticks(rotation=90)

plt.tight_layout()
plt.savefig("D:\Bacteriophage\ESKAPE\Boxplot of open reading frames by the host ESKAPE pathogen.jpg")

# %% [markdown]
# ##### step2. calculates the normalized values

# %%
df_ORF_norm = (df_ORF - df_ORF.min()) / (df_ORF.max() - df_ORF.min())
df_ORF_norm
# Out:
#       Acinobacter baumannii  Campylobacter jejuni  Escherichia coli  \
# 0                  0.000000              0.080952          0.003916
# 1                  0.000000              0.071429               NaN
# 2                  0.003077              0.071429          0.001305
# 3                  0.000000              0.071429          0.003916
# 4                  0.000000              0.080952          0.005222
# ...                     ...                   ...               ...
# 2940                    NaN                   NaN          0.321149
# 2941                    NaN                   NaN          0.356397
# 2942                    NaN                   NaN          0.366841
# 2943                    NaN                   NaN          0.365535
# 2944                    NaN                   NaN          0.383812
#
#       Enterococcus faecium  Haemophilus influenzae  Helicobacter pylori  \
# 0                 0.000000                     1.0             0.763158
# 1                 0.100418                     0.0             0.815789
# 2                 0.288703                     NaN             0.684211
# 3                 0.242678                     NaN             0.842105
# 4                 0.288703                     NaN             0.894737
# ...                    ...                     ...                  ...
# 2940                   NaN                     NaN                  NaN
# 2941                   NaN                     NaN                  NaN
# 2942                   NaN                     NaN                  NaN
# 2943                   NaN                     NaN                  NaN
# 2944                   NaN                     NaN                  NaN
#
#       Pseudomonas aeruginosa  Staphylococcus aureus  Streptococcus pneumoniae  \
# 0                     0.1150               0.000000                  0.038835
# 1                     0.2175               0.000000                  0.009709
# 2                     0.2350               0.219424                  0.699029
# 3                     0.2175               0.223022                  0.019417
# 4                     0.2450               0.248201                  0.543689
# ...                      ...                    ...                       ...
# 2940                     NaN                    NaN                       NaN
# 2941                     NaN                    NaN                       NaN
# 2942                     NaN                    NaN                       NaN
# 2943                     NaN                    NaN                       NaN
# 2944                     NaN                    NaN                       NaN
#
#       Salmonella enterica  Shigella flexneri
# 0                0.413333           0.167247
# 1                0.466667           1.000000
# 2                0.466667           0.254355
# 3                0.000000           0.456446
# 4                0.000000           0.463415
# ...                   ...                ...
# 2940                  NaN                NaN
# 2941                  NaN                NaN
# 2942                  NaN                NaN
# 2943                  NaN                NaN
# 2944                  NaN                NaN
#
# [2945 rows x 11 columns]

# %%
plt.figure(figsize=(15, 6))

colors = ['#1f77b4',
        '#ff7f0e',
        '#2ca02c',
        '#d62728', 
        '#9467bd',
        '#8c564b', 
        '#e377c2',
        '#7f7f7f',
        '#bcbd22',
        '#17becf',
        '#8c6d31'
]

sns.boxplot(data=df_ORF_norm, palette=colors)

plt.xlabel('Species')
plt.ylabel('Number of open reading frames')
plt.title('Boxplot of open reading frames by the host ESKAPE pathogen')

plt.xticks(rotation=90)

plt.tight_layout()
plt.savefig(r"D:\Bacteriophage\ESKAPE\Normalize boxplot of open reading frames by the host ESKAPE pathogen.jpg")

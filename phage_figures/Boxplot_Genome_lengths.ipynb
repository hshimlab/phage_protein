# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## <1> Creates the boxplot of 11 species : Genome lengths
# - Date : 23/06/24
# - Author : Jeesu Lee

# %% [markdown]
# ##### step1. creates the boxplot

# %%
csv_genome_lengths = "D:\Bacteriophage\ESKAPE\Statistics_all_Genome_lengths_final.csv"
df_genome_lengths = pd.read_csv(csv_genome_lengths)

# %%
df_genome_lengths.replace(0, float('nan'), inplace=True)

# %%
plt.figure(figsize=(15, 6))

colors = ['#1f77b4',
        '#ff7f0e',
        '#2ca02c',
        '#d62728', 
        '#9467bd',
        '#8c564b', 
        '#e377c2',
        '#7f7f7f',
        '#bcbd22',
        '#17becf',
        '#8c6d31'
]

sns.boxplot(data=df_genome_lengths, palette=colors)

plt.xlabel('Species')
plt.ylabel('Phage genome lengths (bp)')
plt.title('Boxplot of phage genome lengths (bp) by the host ESKAPE pathogen')

plt.xticks(rotation=90)

plt.tight_layout()
plt.savefig("D:\Bacteriophage\ESKAPE\Boxplot of phage genome lengths (bp) by the host ESKAPE pathogen.jpg")

# %% [markdown]
# ##### step2. calculates the normalized values

# %%
df_genome_lengths_norm = (df_genome_lengths - df_genome_lengths.min()) / (df_genome_lengths.max() - df_genome_lengths.min())
df_genome_lengths_norm
# Out:
#       Acinobacter baumannii  Campylobacter jejuni  Escherichia coli  \
# 0                  0.009167              0.054188          0.001196
# 1                  0.002263              0.049312          0.001913
# 2                  0.008038              0.049367          0.001908
# 3                  0.003111              0.049449          0.001908
# 4                  0.003546              0.053633          0.001913
# ...                     ...                   ...               ...
# 2940                    NaN                   NaN          0.007116
# 2941                    NaN                   NaN          0.004338
# 2942                    NaN                   NaN          0.001323
# 2943                    NaN                   NaN          0.003603
# 2944                    NaN                   NaN          0.003862
#
#       Enterococcus faecium  Haemophilus influenzae  Helicobacter pylori  \
# 0                 0.963226                     1.0             0.793789
# 1                 0.004945                     0.0             0.800927
# 2                 0.114379                     NaN             0.745897
# 3                 0.271704                     NaN             0.812733
# 4                 0.262588                     NaN             0.923159
# ...                    ...                     ...                  ...
# 2940                   NaN                     NaN                  NaN
# 2941                   NaN                     NaN                  NaN
# 2942                   NaN                     NaN                  NaN
# 2943                   NaN                     NaN                  NaN
# 2944                   NaN                     NaN                  NaN
#
#       Pseudomonas aeruginosa  Staphylococcus aureus  Streptococcus pneumoniae  \
# 0                   0.114753               0.001097                  0.029379
# 1                   0.207164               0.001097                  0.016376
# 2                   0.202732               0.150486                  0.714389
# 3                   0.207064               0.165921                  0.646221
# 4                   0.182195               0.161205                  0.019277
# ...                      ...                    ...                       ...
# 2940                     NaN                    NaN                       NaN
# 2941                     NaN                    NaN                       NaN
# 2942                     NaN                    NaN                       NaN
# 2943                     NaN                    NaN                       NaN
# 2944                     NaN                    NaN                       NaN
#
#       Salmonella enterica  Shigella flexneri
# 0                0.118439           0.015807
# 1                0.119211           0.000273
# 2                0.119211           0.003490
# 3                0.002825           0.223808
# 4                0.002825           0.000000
# ...                   ...                ...
# 2940                  NaN                NaN
# 2941                  NaN                NaN
# 2942                  NaN                NaN
# 2943                  NaN                NaN
# 2944                  NaN                NaN
#
# [2945 rows x 11 columns]

# %%
plt.figure(figsize=(15, 6))

colors = ['#1f77b4',
        '#ff7f0e',
        '#2ca02c',
        '#d62728', 
        '#9467bd',
        '#8c564b', 
        '#e377c2',
        '#7f7f7f',
        '#bcbd22',
        '#17becf',
        '#8c6d31'
]

sns.boxplot(data=df_genome_lengths_norm, palette=colors)

plt.xlabel('Species')
plt.ylabel('Phage genome lengths (bp)')
plt.title('Boxplot of phage genome lengths (bp) by the host ESKAPE pathogen')

plt.xticks(rotation=90)

plt.tight_layout()
plt.savefig(r"D:\Bacteriophage\ESKAPE\Normalize boxplot of phage genome lengths (bp) by the host ESKAPE pathogen.jpg")
